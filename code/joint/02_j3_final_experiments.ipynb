# %% [markdown]
# # J3 - Final calibration experiments
#
# Compares `real_only`, `synth_only`, and `mixed_50_50` calibration strategies on the J2 KITTI validation split.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'code' / 'joint'))

from j3_final_experiments import run_j3_final_experiments

# %%
result = run_j3_final_experiments()
result['metrics']
# Out:
# [{'experiment': 'real_only',
#   'class': 'Car',
#   'matched_count': 22,
#   'mean_3d_error': 6.926141262054443,
#   'median_3d_error': 6.116101264953613,
#   'std_3d_error': 4.600998878479004,
#   'mean_depth_error': 6.6334452629089355,
#   'median_depth_error': 5.82598876953125,
#   'std_depth_error': 4.346121311187744,
#   'localization_acc_2m': 0.045454545454545456,
#   'localization_acc_4m': 0.2727272727272727,
#   'scale': -59.70066452026367,
#   'shift': 43.016143798828125,
#   'calibration_pair_count': 185,
#   'calibration_train_rmse_m': 10.67959213256836,
#   'calibration_train_mae_m': 8.499832153320312,
#   'calibration_correlation': -0.730061866316888},
#  {'experiment': 'real_only',
#   'class': 'Pedestrian',
#   'matched_count': 2,
#   'mean_3d_error': 8.25012493133545,
#   'median_3d_error': 8.25012493133545,
#   'std_3d_error': 1.1155383586883545,
#   'mean_depth_error': 7.186500072479248,
#   'median_depth_error': 7.186500072479248,
#   'std_depth_error': 0.9194207191467285,
#   'localization_acc_2m': 0.0,
#   'localization_acc_4m': 0.0,
#   'scale': -59.70066452026367,
#   'shift': 43.016143798828125,
#   'calibration_pair_count': 185,
#   'calibration_train_rmse_m': 10.67959213256836,
#   'calibration_train_mae_m': 8.499832153320312,
#   'calibration_correlation': -0.730061866316888},
#  {'experiment': 'real_only',
#   'class': 'Cyclist',
#   'matched_count': 0,
#   'mean_3d_error': None,
#   'median_3d_error': None,
#   'std_3d_error': None,
#   'mean_depth_error': None,
#   'median_depth_error': None,
#   'std_depth_error': None,
#   'localization_acc_2m': 0.0,
#   'localization_acc_4m': 0.0,
#   'scale': -59.70066452026367,
#   'shift': 43.016143798828125,
#   'calibration_pair_count': 185,
#   'calibration_train_rmse_m': 10.67959213256836,
#   'calibration_train_mae_m': 8.499832153320312,
#   'calibration_correlation': -0.730061866316888},
#  {'experiment': 'synth_only',
#   'class': 'Car',
#   'matched_count': 22,
#   'mean_3d_error': 6.6943440437316895,
#   'median_3d_error': 4.226107597351074,
#   'std_3d_error': 6.755171775817871,
#   'mean_depth_error': 6.430358409881592,
#   'median_depth_error': 4.010563850402832,
#   'std_depth_error': 6.498216152191162,
#   'localization_acc_2m': 0.18181818181818182,
#   'localization_acc_4m': 0.5,
#   'scale': -40.99730682373047,
#   'shift': 36.155887603759766,
#   'calibration_pair_count': 10000,
#   'calibration_train_rmse_m': 11.86688232421875,
#   'calibration_train_mae_m': 8.506599426269531,
#   'calibration_correlation': -0.6468014177964},
#  {'experiment': 'synth_only',
#   'class': 'Pedestrian',
#   'matched_count': 2,
#   'mean_3d_error': 7.8256330490112305,
#   'median_3d_error': 7.8256330490112305,
#   'std_3d_error': 0.8181352615356445,
#   'mean_depth_error': 6.817409992218018,
#   'median_depth_error': 6.817409992218018,
#   'std_depth_error': 0.6627078056335449,
#   'localization_acc_2m': 0.0,
#   'localization_acc_4m': 0.0,
#   'scale': -40.99730682373047,
#   'shift': 36.155887603759766,
#   'calibration_pair_count': 10000,
#   'calibration_train_rmse_m': 11.86688232421875,
#   'calibration_train_mae_m': 8.506599426269531,
#   'calibration_correlation': -0.6468014177964},
#  {'experiment': 'synth_only',
#   'class': 'Cyclist',
#   'matched_count': 0,
#   'mean_3d_error': None,
#   'median_3d_error': None,
#   'std_3d_error': None,
#   'mean_depth_error': None,
#   'median_depth_error': None,
#   'std_depth_error': None,
#   'localization_acc_2m': 0.0,
#   'localization_acc_4m': 0.0,
#   'scale': -40.99730682373047,
#   'shift': 36.155887603759766,
#   'calibration_pair_count': 10000,
#   'calibration_train_rmse_m': 11.86688232421875,
#   'calibration_train_mae_m': 8.506599426269531,
#   'calibration_correlation': -0.6468014177964},
#  {'experiment': 'mixed_50_50',
#   'class': 'Car',
#   'matched_count': 22,
#   'mean_3d_error': 6.838289260864258,
#   'median_3d_error': 5.398459434509277,
#   'std_3d_error': 5.741319179534912,
#   'mean_depth_error': 6.572636604309082,
#   'median_depth_error': 5.134315490722656,
#   'std_depth_error': 5.474411964416504,
#   'localization_acc_2m': 0.22727272727272727,
#   'localization_acc_4m': 0.3181818181818182,
#   'scale': -47.28113555908203,
#   'shift': 39.04157638549805,
#   'calibration_pair_count': 370,
#   'calibration_train_rmse_m': 11.395194053649902,
#   'calibration_train_mae_m': 8.73473834991455,
#   'calibration_correlation': -0.6935845016623919},
#  {'experiment': 'mixed_50_50',
#   'class': 'Pedestrian',
#   'matched_count': 2,
#   'mean_3d_error': 8.631691932678223,
#   'median_3d_error': 8.631691932678223,
#   'std_3d_error': 0.9246261119842529,
#   'mean_depth_error': 7.522240161895752,
#   'median_depth_error': 7.522240161895752,
#   'std_depth_error': 0.7489562034606934,
#   'localization_acc_2m': 0.0,
#   'localization_acc_4m': 0.0,
#   'scale': -47.28113555908203,
#   'shift': 39.04157638549805,
#   'calibration_pair_count': 370,
#   'calibration_train_rmse_m': 11.395194053649902,
#   'calibration_train_mae_m': 8.73473834991455,
#   'calibration_correlation': -0.6935845016623919},
#  {'experiment': 'mixed_50_50',
#   'class': 'Cyclist',
#   'matched_count': 0,
#   'mean_3d_error': None,
#   'median_3d_error': None,
#   'std_3d_error': None,
#   'mean_depth_error': None,
#   'median_depth_error': None,
#   'std_depth_error': None,
#   'localization_acc_2m': 0.0,
#   'localization_acc_4m': 0.0,
#   'scale': -47.28113555908203,
#   'shift': 39.04157638549805,
#   'calibration_pair_count': 370,
#   'calibration_train_rmse_m': 11.395194053649902,
#   'calibration_train_mae_m': 8.73473834991455,
#   'calibration_correlation': -0.6935845016623919}]
