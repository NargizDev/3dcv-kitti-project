# %% [markdown]
# # J1-J2 - Track A + Track B integration
#
# Проверяет совместимость артефактов и запускает первый полный pipeline: YOLO bbox + Track B Depth Anything + calibrated Lift-to-3D.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'code' / 'joint'))

from joint_pipeline import run_j1_j2

# %%
result = run_j1_j2()
result['J2']['metric_summary']
# Out:
# [{'split': 'all',
#   'class': 'Car',
#   'matched_count': 118,
#   'mean_3d_error': 6.975565433502197,
#   'median_3d_error': 5.618134498596191,
#   'std_3d_error': 5.540384292602539,
#   'mean_depth_error': 6.637120246887207,
#   'median_depth_error': 4.947146415710449,
#   'std_depth_error': 5.354233741760254,
#   'localization_acc_2m': 0.1440677966101695,
#   'localization_acc_4m': 0.3644067796610169},
#  {'split': 'all',
#   'class': 'Pedestrian',
#   'matched_count': 22,
#   'mean_3d_error': 8.954497337341309,
#   'median_3d_error': 8.968795776367188,
#   'std_3d_error': 3.0022034645080566,
#   'mean_depth_error': 8.431867599487305,
#   'median_depth_error': 8.326177597045898,
#   'std_depth_error': 2.945603132247925,
#   'localization_acc_2m': 0.045454545454545456,
#   'localization_acc_4m': 0.045454545454545456},
#  {'split': 'all',
#   'class': 'Cyclist',
#   'matched_count': 0,
#   'mean_3d_error': None,
#   'median_3d_error': None,
#   'std_3d_error': None,
#   'mean_depth_error': None,
#   'median_depth_error': None,
#   'std_depth_error': None,
#   'localization_acc_2m': 0.0,
#   'localization_acc_4m': 0.0},
#  {'split': 'train',
#   'class': 'Car',
#   'matched_count': 96,
#   'mean_3d_error': 6.986891269683838,
#   'median_3d_error': 5.286893367767334,
#   'std_3d_error': 5.7339653968811035,
#   'mean_depth_error': 6.637960910797119,
#   'median_depth_error': 4.571802139282227,
#   'std_depth_error': 5.559572696685791,
#   'localization_acc_2m': 0.16666666666666666,
#   'localization_acc_4m': 0.3854166666666667},
#  {'split': 'train',
#   'class': 'Pedestrian',
#   'matched_count': 20,
#   'mean_3d_error': 9.024934768676758,
#   'median_3d_error': 8.968795776367188,
#   'std_3d_error': 3.1201813220977783,
#   'mean_depth_error': 8.556404113769531,
#   'median_depth_error': 8.747937202453613,
#   'std_depth_error': 3.047802209854126,
#   'localization_acc_2m': 0.05,
#   'localization_acc_4m': 0.05},
#  {'split': 'train',
#   'class': 'Cyclist',
#   'matched_count': 0,
#   'mean_3d_error': None,
#   'median_3d_error': None,
#   'std_3d_error': None,
#   'mean_depth_error': None,
#   'median_depth_error': None,
#   'std_depth_error': None,
#   'localization_acc_2m': 0.0,
#   'localization_acc_4m': 0.0},
#  {'split': 'val',
#   'class': 'Car',
#   'matched_count': 22,
#   'mean_3d_error': 6.926141262054443,
#   'median_3d_error': 6.116101264953613,
#   'std_3d_error': 4.600998878479004,
#   'mean_depth_error': 6.6334452629089355,
#   'median_depth_error': 5.82598876953125,
#   'std_depth_error': 4.346121311187744,
#   'localization_acc_2m': 0.045454545454545456,
#   'localization_acc_4m': 0.2727272727272727},
#  {'split': 'val',
#   'class': 'Pedestrian',
#   'matched_count': 2,
#   'mean_3d_error': 8.25012493133545,
#   'median_3d_error': 8.25012493133545,
#   'std_3d_error': 1.1155383586883545,
#   'mean_depth_error': 7.186500072479248,
#   'median_depth_error': 7.186500072479248,
#   'std_depth_error': 0.9194207191467285,
#   'localization_acc_2m': 0.0,
#   'localization_acc_4m': 0.0},
#  {'split': 'val',
#   'class': 'Cyclist',
#   'matched_count': 0,
#   'mean_3d_error': None,
#   'median_3d_error': None,
#   'std_3d_error': None,
#   'mean_depth_error': None,
#   'median_depth_error': None,
#   'std_depth_error': None,
#   'localization_acc_2m': 0.0,
#   'localization_acc_4m': 0.0}]
