# %% [markdown]
# # A4 - 3D localization metrics
#
# Unit-тесты метрик и Track A sanity-check 3D-локализации с oracle depth из matched GT объектов.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'code' / 'track_a'))

from track_a_pipeline import (
    run_a1,
    run_a2,
    run_a3,
    run_a4,
    run_a5,
)

# %%
a4_summary = run_a4()
a4_summary
# Out:
#      class      depth_source anchor  matched_count  mean_3d_error  median_3d_error  std_3d_error  mean_depth_error  median_depth_error  localization_acc_2m  localization_acc_4m
#        Car matched_gt_oracle bottom           2773       0.358445         0.253223      0.352188               0.0                 0.0             0.993148                  1.0
# Pedestrian matched_gt_oracle bottom            330       0.111062         0.087587      0.108795               0.0                 0.0             1.000000                  1.0
#    Cyclist matched_gt_oracle bottom              6       0.099358         0.082028      0.064241               0.0                 0.0             1.000000                  1.0
# {'status': 'ok',
#  'unit_test_report': 'C:\\Users\\User\\Downloads\\3dcv-project\\results\\track_a\\A4_metrics_smoke_test.json',
#  'per_match_metrics': 'C:\\Users\\User\\Downloads\\3dcv-project\\results\\track_a\\A4_metrics_3d_per_match.csv',
#  'summary_metrics': 'C:\\Users\\User\\Downloads\\3dcv-project\\results\\track_a\\metrics_3d.csv',
#  'depth_source': 'matched_gt_oracle_depth_for_track_a_validation',
#  'summary': [{'class': 'Car',
#    'depth_source': 'matched_gt_oracle',
#    'anchor': 'bottom',
#    'matched_count': 2773,
#    'mean_3d_error': 0.35844504833221436,
#    'median_3d_error': 0.2532230615615845,
#    'std_3d_error': 0.352188378572464,
#    'mean_depth_error': 0.0,
#    'median_depth_error': 0.0,
#    'localization_acc_2m': 0.9931482149296791,
#    'localization_acc_4m': 1.0},
#   {'class': 'Pedestrian',
#    'depth_source': 'matched_gt_oracle',
#    'anchor': 'bottom',
#    'matched_count': 330,
#    'mean_3d_error': 0.11106214672327042,
#    'median_3d_error': 0.08758726716041565,
#    'std_3d_error': 0.10879527032375336,
#    'mean_depth_error': 0.0,
#    'median_depth_error': 0.0,
#    'localization_acc_2m': 1.0,
#    'localization_acc_4m': 1.0},
#   {'class': 'Cyclist',
#    'depth_source': 'matched_gt_oracle',
#    'anchor': 'bottom',
#    'matched_count': 6,
#    'mean_3d_error': 0.09935759752988815,
#    'median_3d_error': 0.08202839642763138,
#    'std_3d_error': 0.06424108892679214,
#    'mean_depth_error': 0.0,
#    'median_depth_error': 0.0,
#    'localization_acc_2m': 1.0,
#    'localization_acc_4m': 1.0}]}
