# %% [markdown]
# # A1 - KITTI setup and loader validation
#
# Локальная проверка структуры KITTI, `KITTILoader`, intrinsics, парсинга label-файлов и сохранение `A1_kitti_samples.png`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'code' / 'track_a'))

from track_a_pipeline import (
    run_a1,
    run_a2,
    run_a3,
    run_a4,
    run_a5,
)

# %%
a1_summary = run_a1()
a1_summary
# Out:
# {
#   "status": "ok",
#   "kitti_root": "C:\\Users\\User\\Downloads\\3dcv-project\\data\\kitti\\training",
#   "image_count": 2579,
#   "valid_image_label_calib_count": 958,
#   "sample_frame_id": "000001",
#   "sample_image_shape": [
#     375,
#     1242,
#     3
#   ],
#   "sample_object_count": 3,
#   "sample_p2_shape": [
#     3,
#     4
#   ],
#   "sample_intrinsics": {
#     "fx": 721.5377197265625,
#     "fy": 721.5377197265625,
#     "cx": 609.559326171875,
#     "cy": 172.85400390625
#   },
#   "classes_in_sample": [
#     "Car",
#     "Cyclist",
#     "Truck"
#   ],
#   "sample_visualization": "C:\\Users\\User\\Downloads\\3dcv-project\\results\\track_a\\A1_kitti_samples.png"
# }
# {'status': 'ok',
#  'kitti_root': 'C:\\Users\\User\\Downloads\\3dcv-project\\data\\kitti\\training',
#  'image_count': 2579,
#  'valid_image_label_calib_count': 958,
#  'sample_frame_id': '000001',
#  'sample_image_shape': [375, 1242, 3],
#  'sample_object_count': 3,
# ...
