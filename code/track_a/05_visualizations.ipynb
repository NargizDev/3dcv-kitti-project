# %% [markdown]
# # A5 - Visualization demo
#
# Демо функций визуализации: 2D bbox, oracle-depth overlay и BEV для Lift-to-3D sanity-check.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'code' / 'track_a'))

from track_a_pipeline import (
    run_a1,
    run_a2,
    run_a3,
    run_a4,
    run_a5,
)

# %%
a5_summary = run_a5()
a5_summary
# Out:
# {
#   "status": "ok",
#   "frame_id": "004139",
#   "visualization": "C:\\Users\\User\\Downloads\\3dcv-project\\results\\track_a\\A5_visualization_demo.png",
#   "detections": 16,
#   "gt_objects": 22,
#   "matched_3d_objects": 11
# }
# {'status': 'ok',
#  'frame_id': '004139',
#  'visualization': 'C:\\Users\\User\\Downloads\\3dcv-project\\results\\track_a\\A5_visualization_demo.png',
#  'detections': 16,
#  'gt_objects': 22,
#  'matched_3d_objects': 11}
