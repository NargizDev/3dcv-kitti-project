# %% [markdown]
# # A3 - Lift-to-3D validation
#
# Проверка back-projection на искусственной карте глубины, где внутри GT bbox подставляется GT Z из KITTI.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'code' / 'track_a'))

from track_a_pipeline import (
    run_a1,
    run_a2,
    run_a3,
    run_a4,
    run_a5,
)

# %%
a3_summary = run_a3()
a3_summary
# Out:
# anchor  count  mean_abs_x_error  median_abs_x_error  mean_abs_y_error  median_abs_y_error  mean_abs_z_error  median_abs_z_error  mean_euclidean_error  median_euclidean_error
# bottom    218          0.188303            0.069961          0.172181            0.117876               0.0                 0.0              0.279624                0.148358
# center    218          0.188303            0.069961          0.737287            0.715139               0.0                 0.0              0.803663                0.723911
# {'status': 'ok',
#  'checked_frames_with_cars': 50,
#  'checks_path': 'C:\\Users\\User\\Downloads\\3dcv-project\\results\\track_a\\A3_lift_to_3d_checks.csv',
#  'summary_by_anchor': [{'anchor': 'bottom',
#    'count': 218,
#    'mean_abs_x_error': 0.18830289315739904,
#    'median_abs_x_error': 0.06996089220046997,
#    'mean_abs_y_error': 0.17218080313380704,
#    'median_abs_y_error': 0.11787563562393188,
#    'mean_abs_z_error': 0.0,
# ...
