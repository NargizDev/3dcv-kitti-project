# %% [markdown]
# # A2 - YOLOv8 inference on KITTI
#
# Запуск pre-trained YOLOv8 на локальных KITTI image_2, сохранение JSON-предсказаний и 2D-метрик P/R/F1/AP50. По умолчанию используется `yolov8n.pt`, потому что локальная машина работает на CPU. Для Colab можно задать `TRACK_A_YOLO_MODEL=yolov8m.pt`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'code' / 'track_a'))

from track_a_pipeline import (
    run_a1,
    run_a2,
    run_a3,
    run_a4,
    run_a5,
)

# %%
a2_summary = run_a2()
a2_summary
# Out:
# YOLO progress: 1/2579 frames, written=1, skipped=0
# YOLO progress: 100/2579 frames, written=100, skipped=0
# YOLO progress: 200/2579 frames, written=200, skipped=0
# YOLO progress: 300/2579 frames, written=300, skipped=0
# YOLO progress: 400/2579 frames, written=400, skipped=0
# YOLO progress: 500/2579 frames, written=500, skipped=0
# YOLO progress: 600/2579 frames, written=600, skipped=0
# YOLO progress: 700/2579 frames, written=700, skipped=0
# YOLO progress: 800/2579 frames, written=800, skipped=0
# YOLO progress: 900/2579 frames, written=900, skipped=0
# YOLO progress: 1000/2579 frames, written=1000, skipped=0
# YOLO progress: 1100/2579 frames, written=1100, skipped=0
# YOLO progress: 1200/2579 frames, written=1200, skipped=0
# YOLO progress: 1300/2579 frames, written=1300, skipped=0
# YOLO progress: 1400/2579 frames, written=1400, skipped=0
# YOLO progress: 1500/2579 frames, written=1500, skipped=0
# YOLO progress: 1600/2579 frames, written=1600, skipped=0
# ...
